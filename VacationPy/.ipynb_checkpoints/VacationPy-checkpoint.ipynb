# %% [markdown]
# # VacationPy

# %% [markdown]
# ## Imports

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import gmaps
import os
import json

# Import API key
from api_keys import g_key

# %% [markdown]
# ## Storing results as DataFrame

# %%
# Reading in and displaying the csv file
cities_df = pd.read_csv("../WeatherPy/city_weather_data.csv")
cities_df.head()
# Out:
#     Latitude   Longitude            City Country  Max Temperature (F)  \
# 0 -14.936039   13.322562         lubango      ao                69.80
# 1  39.658409  -48.245995          torbay      ca                28.99
# 2 -89.979413   37.550464  port elizabeth      za                71.60
# 3 -35.580137  165.168906         ahipara      nz                65.88
# 4 -63.583940  -38.583740         ushuaia      ar                41.00
#
#    Humidity  Cloudiness  Wind Speed (mph)        Date
# 0      56.0         0.0              3.44  1610528669
# 1      93.0        75.0              8.05  1610528850
# 2      83.0        90.0             13.80  1610528788
# 3      84.0        10.0              6.15  1610528850
# 4      75.0         0.0              8.05  1610528649

# %% [markdown]
# ## Humidity Heatmap

# %%
# Creating a heat map that displays the humidity for every city from WeatherPy

# Configuring gmaps with API key
gmaps.configure(api_key=g_key)

# Storing Latitude and Longitude values into locations 
locations = cities_df[["Latitude", "Longitude"]]

# Storing Humidity as the weight
humidity = cities_df["Humidity"]

# %%
# Creating the map and a humidity Heatmap layer
fig = gmaps.figure(center=(20, 0), zoom_level= 2)

# Setting the variables for the heat layer
heat_layer = gmaps.heatmap_layer(locations, weights=humidity, 
                                 dissipating=False, max_intensity=100,
                                 point_radius = 3.5)

# Adding the heatlayer
fig.add_layer(heat_layer)

# Displaying the heatmap
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %% [markdown]
# ## Specific Weather Criteria

# %%
# Narrowing down the DataFrame to find ideal weather conditions: 

ideal_weather = cities_df.loc[((cities_df["Max Temperature (F)"] >= 65) & 
                               (cities_df["Max Temperature (F)"] <= 95) & 
                               (cities_df["Wind Speed (mph)"] <= 18) & 
                               (cities_df["Cloudiness"] <= 15)), :]

# %% [markdown]
# ## Hotel Map

# %%
# Using Google Places API to find the first hotel for each city located within 5000 meters of the coordinates.

# Setting dataframe as hotel_df.
hotel_df = ideal_weather.copy()

# Resetting index
hotel_df = hotel_df.reset_index(drop=True)

# Adding a "Hotel Name" column to the DataFrame
hotel_df["Hotel Name"] = ""

hotel_df
# Out:
#      Latitude   Longitude                   City Country  Max Temperature (F)  \
# 0  -14.936039   13.322562                lubango      ao                69.80
# 1  -35.580137  165.168906                ahipara      nz                65.88
# 2  -56.473162  104.629318              busselton      au                81.00
# 3  -53.198595  -17.768423        arraial do cabo      br                75.20
# 4  -33.583648  130.542010               flinders      au                73.99
# 5   34.992028 -153.096680                  kapaa      us                73.40
# 6  -65.254553 -129.726240                rikitea      pf                77.76
# 7  -27.198298  147.966471                   roma      au                84.20
# 8    9.507956   -8.297668                odienne      ci                77.77
# 9   15.436669 -139.951558                   hilo      us                69.80
# 10  19.139303   -3.529688               araouane      ml                66.85
# ...

# %%
# Using the Google Places API for each city's coordinates.
# Adding the first Hotel result to the DataFrame.

# Creating empty list for hotel names
hotels = []

# Base url
base_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"

# Using iterrows to iterate through hotel_df
for index, row in hotel_df.iterrows():

    # setting parameters and geocoordinates to search for hotels with 5000 meters of coordinates
    city = row['City']
    lat = row['Latitude']
    long = row['Longitude']
    locations = f"{lat},{long}"
    target_search = "hotel"
    target_radius = 5000
    target_type = "lodging"
                              
    # Creating a parameters dictionary
    params = {"location": locations, 
              "keyword": target_search, 
              "radius": target_radius, 
              "type": target_type, 
              "key": g_key}                            
      
    print("--------------------------------------")  
    print(f"Retrieving Results for Index: {city}.")
    
    # Adding results to hotel_df using try and except incase there is no data    
    try:    
        # Running a request using the params dictionary
        response = requests.get(base_url, params=params)

        # Converting response to json
        hotel_data = response.json()    
     
        # Appending the hotel to the hotel list    
        hotels.append(hotel_data["results"][0]["name"])    
    
        print("Results Found")
    
    except IndexError:
        # Printing message if IndexError occurs and appending NaN
        print("Unable to retrieve results... skipping.")
        hotels.append(np.nan)    
    
# Adding the list of hotels thotel_df
hotel_df["Hotel Name"] = hotels
# Out:
# --------------------------------------
# Retrieving Results for Index: lubango.
# Unable to retrieve results... skipping.
# --------------------------------------
# Retrieving Results for Index: ahipara.
# Unable to retrieve results... skipping.
# --------------------------------------
# Retrieving Results for Index: busselton.
# Unable to retrieve results... skipping.
# --------------------------------------
# Retrieving Results for Index: arraial do cabo.
# Unable to retrieve results... skipping.
# --------------------------------------
# Retrieving Results for Index: flinders.
# Unable to retrieve results... skipping.
# --------------------------------------
# Retrieving Results for Index: kapaa.
# Unable to retrieve results... skipping.
# --------------------------------------
# Retrieving Results for Index: rikitea.
# Unable to retrieve results... skipping.
# --------------------------------------
# Retrieving Results for Index: roma.
# Unable to retrieve results... skipping.
# ...

# %%
# Cleaning the dataframe to remove the rows with no hotel information 
hotel_df = hotel_df.dropna()
hotel_df
# Out:
#      Latitude   Longitude         City Country  Max Temperature (F)  Humidity  \
# 13 -23.384844  -52.778035     cianorte      br                73.40      88.0
# 28  17.209428   80.409976      khammam      in                89.58      34.0
# 38  26.115415   84.579127  maharajganj      in                69.80      39.0
# 47  17.212518  103.140275     nong han      th                78.01      31.0
# 49 -28.018945   18.769971    karasburg      na                88.12      33.0
#
#     Cloudiness  Wind Speed (mph)        Date                     Hotel Name
# 13         0.0              4.61  1610528879                   Hudson Hotel
# 28        12.0              3.38  1610528919             Boddu Sreenu Hotel
# 38         0.0              4.14  1610528947  Dharmdeo jee tea shop (hotel)
# 47         0.0              3.44  1610528964            James & oi homestay
# 49         2.0              6.22  1610528972            U&K Bed & Breakfast

# %%
# Using the template to add the hotel marks to the heatmap
info_box_template = """
<dl>
<dt>Name</dt><dd>{Hotel Name}</dd>
<dt>City</dt><dd>{City}</dd>
<dt>Country</dt><dd>{Country}</dd>
</dl>
"""
# Storing the DataFrame Row
hotel_info = [info_box_template.format(**row) for index, row in hotel_df.iterrows()]
locations = hotel_df[["Latitude", "Longitude"]]

# %%
#Plotting markers on top of the heatmap

# Assigning the marker layer to a variable
markers = gmaps.marker_layer(locations, info_box_content = hotel_info)

# Adding the layer to the map
fig.add_layer(markers)

# Displaying the map
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))
